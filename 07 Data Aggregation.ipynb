# %% [markdown]
# # Data Aggregation
# #### Table of Contents
# 1. Basics
# 2. Filtering data based on conditions
#     - with mathematical operation
#     - ```isin()```
# 3. ```groupby()```

# %% [markdown]
# ## Basics
# - Data Aggregation refers to identifying data satisfying a condition.
# - It helps in studying one or more aggregated groups together.

# %%
import pandas as pd

# %% [markdown]
# ## Filtering data based on conditions

# %%
data = pd.read_csv("Data_sets/superstore_dataset2011-2015.csv", encoding = "ISO-8859-1")
data.shape
# Out:
# (51290, 24)

# %%
data.head(2)
# Out:
#    Row ID       Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0   42433   AG-2011-2040   1/1/2011  6/1/2011  Standard Class    TB-11280
# 1   22253  IN-2011-47883   1/1/2011  8/1/2011  Standard Class    JH-15985
#
#      Customer Name   Segment         City            State  ...  \
# 0  Toby Braunhardt  Consumer  Constantine      Constantine  ...
# 1      Joseph Holt  Consumer  Wagga Wagga  New South Wales  ...
#
#          Product ID         Category Sub-Category              Product Name  \
# 0  OFF-TEN-10000025  Office Supplies      Storage       Tenex Lockers, Blue
# 1   OFF-SU-10000618  Office Supplies     Supplies  Acme Trimmer, High Speed
#
#      Sales Quantity Discount   Profit  Shipping Cost  Order Priority
# 0  408.300        2      0.0  106.140          35.46          Medium
# 1  120.366        3      0.1   36.036           9.72          Medium
#
# [2 rows x 24 columns]

# %%
data.tail(2)
# Out:
#        Row ID        Order ID  Order Date Ship Date       Ship Mode  \
# 51288    6852  MX-2014-114783  31-12-2014  6/1/2015  Standard Class
# 51289   36388  CA-2014-156720  31-12-2014  4/1/2015  Standard Class
#
#       Customer ID  Customer Name   Segment      City      State  ...  \
# 51288    TD-20995  Tamara Dahlen  Consumer    Juárez  Chihuahua  ...
# 51289    JM-15580  Jill Matthias  Consumer  Loveland   Colorado  ...
#
#             Product ID         Category Sub-Category  \
# 51288  OFF-LA-10000413  Office Supplies       Labels
# 51289  OFF-FA-10003472  Office Supplies    Fasteners
#
#                                  Product Name  Sales Quantity Discount  \
# 51288  Hon Legal Exhibit Labels, Alphabetical  7.120        1      0.0
# 51289                     Bagged Rubber Bands  3.024        3      0.2
#
#        Profit  Shipping Cost  Order Priority
# 51288  0.5600           0.20          Medium
# 51289 -0.6048           0.17          Medium
#
# [2 rows x 24 columns]

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
data['Order Priority'].unique()
# Out:
# array(['Medium', 'High', 'Critical', 'Low'], dtype=object)

# %%
data['Quantity'].unique()
# Out:
# array([ 2,  3,  4,  5,  1,  6,  8,  7,  9, 12, 14, 11, 10, 13],
#       dtype=int64)

# %%
data[data.Quantity > 10]
# Out:
#        Row ID         Order ID  Order Date  Ship Date       Ship Mode  \
# 61      12529  ES-2011-1416586    1/3/2011   4/3/2011    Second Class
# 106     16113  ES-2011-5940123    1/6/2011   4/6/2011    Second Class
# 144      2107   MX-2011-126641    1/7/2011   3/7/2011     First Class
# 235     48321     SA-2011-1130   1/11/2011  2/11/2011     First Class
# 279     35364   CA-2011-102673   1/11/2011  5/11/2011  Standard Class
# ...       ...              ...         ...        ...             ...
# 50934   32726   US-2012-164448  31-10-2012  4/11/2012    Second Class
# 51024   33008   CA-2014-123491  31-10-2014  6/11/2014  Standard Class
# 51028    3312   US-2014-127026  31-10-2014  4/11/2014  Standard Class
# 51125   33621   CA-2012-109470  31-12-2012   3/1/2013    Second Class
# 51258   48786     UP-2014-3330  31-12-2014   2/1/2015     First Class
#
#       Customer ID    Customer Name      Segment               City  \
# ...

# %%
data[data["Order Priority"] == "Critical"].head()
# Out:
#     Row ID       Order ID Order Date Ship Date     Ship Mode Customer ID  \
# 6    21613  IN-2011-30733   1/2/2011  3/2/2011  Second Class    PO-18865
# 8    44508   AO-2011-1390   1/2/2011  4/2/2011  Second Class     DK-3150
# 9    23688  ID-2011-56493   1/2/2011  3/2/2011  Second Class    SP-20650
# 14   21615  IN-2011-30733   1/2/2011  3/2/2011  Second Class    PO-18865
# 17   21614  IN-2011-30733   1/2/2011  3/2/2011  Second Class    PO-18865
#
#         Customer Name    Segment       City   State  ...        Product ID  \
# 6   Patrick O'Donnell   Consumer      Dhaka   Dhaka  ...   TEC-CO-10002316
# 8      David Kendrick  Corporate     Luanda  Luanda  ...  OFF-FEL-10001541
# 9    Stephanie Phelps  Corporate  Yingcheng   Hubei  ...   OFF-ST-10002161
# 14  Patrick O'Donnell   Consumer      Dhaka   Dhaka  ...   OFF-SU-10000484
# 17  Patrick O'Donnell   Consumer      Dhaka   Dhaka  ...   OFF-BI-10003012
#
# ...

# %%
data[(data["Segment"] == "Corporate") & (data["Order Priority"] == "Critical")].head()
# Out:
#      Row ID        Order ID Order Date Ship Date     Ship Mode Customer ID  \
# 8     44508    AO-2011-1390   1/2/2011  4/2/2011  Second Class     DK-3150
# 9     23688   ID-2011-56493   1/2/2011  3/2/2011  Second Class    SP-20650
# 116    2730  MX-2011-137946   1/6/2011  3/6/2011   First Class    CB-12535
# 144    2107  MX-2011-126641   1/7/2011  3/7/2011   First Class    FW-14395
# 145    2109  MX-2011-126641   1/7/2011  3/7/2011   First Class    FW-14395
#
#         Customer Name    Segment               City             State  ...  \
# 8      David Kendrick  Corporate             Luanda            Luanda  ...
# 9    Stephanie Phelps  Corporate          Yingcheng             Hubei  ...
# 116  Claudia Bergmann  Corporate        Mexico City  Distrito Federal  ...
# 144    Fred Wasserman  Corporate  Antiguo Cuscatlán       La Libertad  ...
# 145    Fred Wasserman  Corporate  Antiguo Cuscatlán       La Libertad  ...
#
#            Product ID         Category Sub-Category  \
# ...

# %%
data.head(2)
# Out:
#    Row ID       Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0   42433   AG-2011-2040   1/1/2011  6/1/2011  Standard Class    TB-11280
# 1   22253  IN-2011-47883   1/1/2011  8/1/2011  Standard Class    JH-15985
#
#      Customer Name   Segment         City            State  ...  \
# 0  Toby Braunhardt  Consumer  Constantine      Constantine  ...
# 1      Joseph Holt  Consumer  Wagga Wagga  New South Wales  ...
#
#          Product ID         Category Sub-Category              Product Name  \
# 0  OFF-TEN-10000025  Office Supplies      Storage       Tenex Lockers, Blue
# 1   OFF-SU-10000618  Office Supplies     Supplies  Acme Trimmer, High Speed
#
#      Sales Quantity Discount   Profit  Shipping Cost  Order Priority
# 0  408.300        2      0.0  106.140          35.46          Medium
# 1  120.366        3      0.1   36.036           9.72          Medium
#
# [2 rows x 24 columns]

# %%
data['Sub-Category'].unique()
# Out:
# array(['Storage', 'Supplies', 'Paper', 'Furnishings', 'Copiers',
#        'Bookcases', 'Appliances', 'Art', 'Accessories', 'Binders',
#        'Labels', 'Envelopes', 'Chairs', 'Machines', 'Tables', 'Phones',
#        'Fasteners'], dtype=object)

# %% [markdown]
# ### isin()

# %%
# isin is simple method of or
data[data['Sub-Category'].isin(['Chairs', 'Tables'])].head()
# Out:
#     Row ID         Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 27   37844   CA-2011-113880   1/3/2011  5/3/2011  Standard Class    VF-21715
# 28   44230     CA-2011-1800   1/3/2011  4/3/2011     First Class    TP-11415
# 29   13131  ES-2011-1705541   1/3/2011  6/3/2011  Standard Class    TS-21370
# 32   31454   CA-2011-104269   1/3/2011  6/3/2011    Second Class    DB-13060
# 34   39607   CA-2011-168312   1/3/2011  7/3/2011  Standard Class    GW-14605
#
#        Customer Name      Segment         City       State  ...  \
# 27    Vicky Freymann  Home Office     Elmhurst    Illinois  ...
# 28      Tom Prescott     Consumer      Toronto     Ontario  ...
# 29      Todd Sumrall    Corporate  Farnborough     England  ...
# 32       Dave Brooks     Consumer      Seattle  Washington  ...
# 34  Giulietta Weimer     Consumer      Houston       Texas  ...
#
#           Product ID   Category Sub-Category  \
# 27   FUR-CH-10000863  Furniture       Chairs
# ...

# %% [markdown]
# ##

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({'location':list('AAAAABBBBB'),
                   'rain':pd.Series(100 + 50*np.random.randn(10)),
                   'temp':pd.Series(28 + 10*np.random.randn(10))
})
replacements = {
'location': {'A':'Hyderabad', 'B':'Mumbai'}
}
df = df.replace(replacements, regex=True)
print(df.head(2))
# Out:
#     location        rain       temp
# 0  Hyderabad  121.158144  41.302198
# 1  Hyderabad  183.692204  22.734634

# %% [markdown]
# ### contains()

# %%
mumbai_data = df.loc[df.location.str.contains('umb'),:]

print(mumbai_data.head(2))
# Out:
#   location        rain       temp
# 5   Mumbai  107.613010  29.011289
# 6   Mumbai  143.661063   7.505059

# %% [markdown]
# ## Grouping Data
# - ```groupby``` method can be used to group data and perform various function on each group.

# %%
regions = df.groupby('location')
print(regions.mean())
# Out:
#                  rain       temp
# location
# Hyderabad   94.706214  30.426660
# Mumbai     122.498725  16.615397

# %%
print(dir(regions))
# Out:
# ['__annotations__', '__class__', '__class_getitem__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__orig_bases__', '__parameters__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_accessors', '_agg_examples_doc', '_agg_general', '_agg_py_fallback', '_aggregate_frame', '_aggregate_item_by_item', '_aggregate_with_numba', '_apply_allowlist', '_apply_filter', '_apply_to_column_groupbys', '_ascending_count', '_bool_agg', '_cache', '_can_use_transform_fast', '_choose_path', '_concat_objects', '_constructor', '_cumcount_array', '_cython_agg_general', '_cython_transform', '_define_paths', '_descending_count', '_dir_additions', '_dir_deletions', '_fill', '_get_cythonized_result', '_get_dat
# ...

# %%
aggregate method

# %%
filter method
